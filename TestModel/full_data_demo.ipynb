# %%
import pandas as pd
import torch 
import torch.nn as nn
from torch.utils.data import DataLoader,Dataset
import numpy as np
from tqdm import tqdm
import pandas as pd
import slugify
import os
# import dask.dataframe as dd

FULL_DATA_DIR = '/content'

# %%
path="/content/"
targetpath ="train.ftr"
valpath = "val.ftr"
testpath ="test.csv"

# %%
# df= pd.read_csv(path+valpath)

# %%
# 把全量数据（target、val）分别保存到path/targetpath和path/valpath
def GetDataFromKaggle():
    print('setting up kaggle...')
    os.system("pip install --upgrade --force-reinstall --no-deps kaggle==1.5.8")
    os.system("mkdir /root/.kaggle")
    with open("kaggle.json", "w+") as f:
        f.write('{"username":"zhuyuhe16","key":"6176383558b0033d473ee3714a957b7f"}')
    os.system("mkdir ~/kaggle_data")
    os.system("sudo cp kaggle.json ~/.kaggle/kaggle.json")
    os.system("chmod 600 /root/.kaggle/kaggle.json")
    print('downloading files from kaggle...')
    os.system("kaggle competitions download -c ubiquant-market-prediction")
    os.system("mv ubiquant-market-prediction.zip " + FULL_DATA_DIR + "/ubiquant-market-prediction.zip")
    os.system("unzip -oq /content/ubiquant-market-prediction.zip -d " + FULL_DATA_DIR)
    
    print('data preprocessing...')
    df = pd.read_csv("/content/train.csv",
                dtype = {'row_id': 'O',
                        'time_id': 'int16',
                        'investment_id': 'int16',
                        'target': 'float16',
                        'f_0': 'float16',
                        'f_1': 'float16',
                        'f_2': 'float16',
                        'f_3': 'float16',
                        'f_4': 'float16',
                        'f_5': 'float16',
                        'f_6': 'float16',
                        'f_7': 'float16',
                        'f_8': 'float16',
                        'f_9': 'float16',
                        'f_10': 'float16',
                        'f_11': 'float16',
                        'f_12': 'float16',
                        'f_13': 'float16',
                        'f_14': 'float16',
                        'f_15': 'float16',
                        'f_16': 'float16',
                        'f_17': 'float16',
                        'f_18': 'float16',
                        'f_19': 'float16',
                        'f_20': 'float16',
                        'f_21': 'float16',
                        'f_22': 'float16',
                        'f_23': 'float16',
                        'f_24': 'float16',
                        'f_25': 'float16',
                        'f_26': 'float16',
                        'f_27': 'float16',
                        'f_28': 'float16',
                        'f_29': 'float16',
                        'f_30': 'float16',
                        'f_31': 'float16',
                        'f_32': 'float16',
                        'f_33': 'float16',
                        'f_34': 'float16',
                        'f_35': 'float16',
                        'f_36': 'float16',
                        'f_37': 'float16',
                        'f_38': 'float16',
                        'f_39': 'float16',
                        'f_40': 'float16',
                        'f_41': 'float16',
                        'f_42': 'float16',
                        'f_43': 'float16',
                        'f_44': 'float16',
                        'f_45': 'float16',
                        'f_46': 'float16',
                        'f_47': 'float16',
                        'f_48': 'float16',
                        'f_49': 'float16',
                        'f_50': 'float16',
                        'f_51': 'float16',
                        'f_52': 'float16',
                        'f_53': 'float16',
                        'f_54': 'float16',
                        'f_55': 'float16',
                        'f_56': 'float16',
                        'f_57': 'float16',
                        'f_58': 'float16',
                        'f_59': 'float16',
                        'f_60': 'float16',
                        'f_61': 'float16',
                        'f_62': 'float16',
                        'f_63': 'float16',
                        'f_64': 'float16',
                        'f_65': 'float16',
                        'f_66': 'float16',
                        'f_67': 'float16',
                        'f_68': 'float16',
                        'f_69': 'float16',
                        'f_70': 'float16',
                        'f_71': 'float16',
                        'f_72': 'float16',
                        'f_73': 'float16',
                        'f_74': 'float16',
                        'f_75': 'float16',
                        'f_76': 'float16',
                        'f_77': 'float16',
                        'f_78': 'float16',
                        'f_79': 'float16',
                        'f_80': 'float16',
                        'f_81': 'float16',
                        'f_82': 'float16',
                        'f_83': 'float16',
                        'f_84': 'float16',
                        'f_85': 'float16',
                        'f_86': 'float16',
                        'f_87': 'float16',
                        'f_88': 'float16',
                        'f_89': 'float16',
                        'f_90': 'float16',
                        'f_91': 'float16',
                        'f_92': 'float16',
                        'f_93': 'float16',
                        'f_94': 'float16',
                        'f_95': 'float16',
                        'f_96': 'float16',
                        'f_97': 'float16',
                        'f_98': 'float16',
                        'f_99': 'float16',
                        'f_100': 'float16',
                        'f_101': 'float16',
                        'f_102': 'float16',
                        'f_103': 'float16',
                        'f_104': 'float16',
                        'f_105': 'float16',
                        'f_106': 'float16',
                        'f_107': 'float16',
                        'f_108': 'float16',
                        'f_109': 'float16',
                        'f_110': 'float16',
                        'f_111': 'float16',
                        'f_112': 'float16',
                        'f_113': 'float16',
                        'f_114': 'float16',
                        'f_115': 'float16',
                        'f_116': 'float16',
                        'f_117': 'float16',
                        'f_118': 'float16',
                        'f_119': 'float16',
                        'f_120': 'float16',
                        'f_121': 'float16',
                        'f_122': 'float16',
                        'f_123': 'float16',
                        'f_124': 'float16',
                        'f_125': 'float16',
                        'f_126': 'float16',
                        'f_127': 'float16',
                        'f_128': 'float16',
                        'f_129': 'float16',
                        'f_130': 'float16',
                        'f_131': 'float16',
                        'f_132': 'float16',
                        'f_133': 'float16',
                        'f_134': 'float16',
                        'f_135': 'float16',
                        'f_136': 'float16',
                        'f_137': 'float16',
                        'f_138': 'float16',
                        'f_139': 'float16',
                        'f_140': 'float16',
                        'f_141': 'float16',
                        'f_142': 'float16',
                        'f_143': 'float16',
                        'f_144': 'float16',
                        'f_145': 'float16',
                        'f_146': 'float16',
                        'f_147': 'float16',
                        'f_148': 'float16',
                        'f_149': 'float16',
                        'f_150': 'float16',
                        'f_151': 'float16',
                        'f_152': 'float16',
                        'f_153': 'float16',
                        'f_154': 'float16',
                        'f_155': 'float16',
                        'f_156': 'float16',
                        'f_157': 'float16',
                        'f_158': 'float16',
                        'f_159': 'float16',
                        'f_160': 'float16',
                        'f_161': 'float16',
                        'f_162': 'float16',
                        'f_163': 'float16',
                        'f_164': 'float16',
                        'f_165': 'float16',
                        'f_166': 'float16',
                        'f_167': 'float16',
                        'f_168': 'float16',
                        'f_169': 'float16',
                        'f_170': 'float16',
                        'f_171': 'float16',
                        'f_172': 'float16',
                        'f_173': 'float16',
                        'f_174': 'float16',
                        'f_175': 'float16',
                        'f_176': 'float16',
                        'f_177': 'float16',
                        'f_178': 'float16',
                        'f_179': 'float16',
                        'f_180': 'float16',
                        'f_181': 'float16',
                        'f_182': 'float16',
                        'f_183': 'float16',
                        'f_184': 'float16',
                        'f_185': 'float16',
                        'f_186': 'float16',
                        'f_187': 'float16',
                        'f_188': 'float16',
                        'f_189': 'float16',
                        'f_190': 'float16',
                        'f_191': 'float16',
                        'f_192': 'float16',
                        'f_193': 'float16',
                        'f_194': 'float16',
                        'f_195': 'float16',
                        'f_196': 'float16',
                        'f_197': 'float16',
                        'f_198': 'float16',
                        'f_199': 'float16',
                        'f_200': 'float16',
                        'f_201': 'float16',
                        'f_202': 'float16',
                        'f_203': 'float16',
                        'f_204': 'float16',
                        'f_205': 'float16',
                        'f_206': 'float16',
                        'f_207': 'float16',
                        'f_208': 'float16',
                        'f_209': 'float16',
                        'f_210': 'float16',
                        'f_211': 'float16',
                        'f_212': 'float16',
                        'f_213': 'float16',
                        'f_214': 'float16',
                        'f_215': 'float16',
                        'f_216': 'float16',
                        'f_217': 'float16',
                        'f_218': 'float16',
                        'f_219': 'float16',
                        'f_220': 'float16',
                        'f_221': 'float16',
                        'f_222': 'float16',
                        'f_223': 'float16',
                        'f_224': 'float16',
                        'f_225': 'float16',
                        'f_226': 'float16',
                        'f_227': 'float16',
                        'f_228': 'float16',
                        'f_229': 'float16',
                        'f_230': 'float16',
                        'f_231': 'float16',
                        'f_232': 'float16',
                        'f_233': 'float16',
                        'f_234': 'float16',
                        'f_235': 'float16',
                        'f_236': 'float16',
                        'f_237': 'float16',
                        'f_238': 'float16',
                        'f_239': 'float16',
                        'f_240': 'float16',
                        'f_241': 'float16',
                        'f_242': 'float16',
                        'f_243': 'float16',
                        'f_244': 'float16',
                        'f_245': 'float16',
                        'f_246': 'float16',
                        'f_247': 'float16',
                        'f_248': 'float16',
                        'f_249': 'float16',
                        'f_250': 'float16',
                        'f_251': 'float16',
                        'f_252': 'float16',
                        'f_253': 'float16',
                        'f_254': 'float16',
                        'f_255': 'float16',
                        'f_256': 'float16',
                        'f_257': 'float16',
                        'f_258': 'float16',
                        'f_259': 'float16',
                        'f_260': 'float16',
                        'f_261': 'float16',
                        'f_262': 'float16',
                        'f_263': 'float16',
                        'f_264': 'float16',
                        'f_265': 'float16',
                        'f_266': 'float16',
                        'f_267': 'float16',
                        'f_268': 'float16',
                        'f_269': 'float16',
                        'f_270': 'float16',
                        'f_271': 'float16',
                        'f_272': 'float16',
                        'f_273': 'float16',
                        'f_274': 'float16',
                        'f_275': 'float16',
                        'f_276': 'float16',
                        'f_277': 'float16',
                        'f_278': 'float16',
                        'f_279': 'float16',
                        'f_280': 'float16',
                        'f_281': 'float16',
                        'f_282': 'float16',
                        'f_283': 'float16',
                        'f_284': 'float16',
                        'f_285': 'float16',
                        'f_286': 'float16',
                        'f_287': 'float16',
                        'f_288': 'float16',
                        'f_289': 'float16',
                        'f_290': 'float16',
                        'f_291': 'float16',
                        'f_292': 'float16',
                        'f_293': 'float16',
                        'f_294': 'float16',
                        'f_295': 'float16',
                        'f_296': 'float16',
                        'f_297': 'float16',
                        'f_298': 'float16',
                        'f_299': 'float16'})
    
    train = df.sample(frac=0.8, random_state=11785, axis=0).reset_index(drop=True)
    val = df[~df.index.isin(train.index)].reset_index(drop=True)
    train.to_feather(path + targetpath)
    val.to_feather(path + valpath)
    print('data is all set!')

# %%
#两方面去考虑attention,首先,可以忽视事件数据,将所有Id一样的人聚集在一起,将他们视作一个sequence,将他们的target作为另一个,观察两个sequence的关系
#其次,可以以同一个时域做Attention,将这个时域中的数据作为一个切面sequence,然后跟他们的结果做相关性

# %%
def GetMaxFeature(x):
    id_size = x["investment_id"].nunique()
    time_id_size = x["time_id"].nunique()
    return id_size,time_id_size

# %%
class Ubiquant(Dataset):
    def __init__(self,datapath,context = 100,train_data = True,get_time_data = True):
        super(Ubiquant,self).__init__()
        self.get_time = get_time_data
        if(train_data):
            self.data = pd.read_feather(datapath)
            self.id_size,self.time_size = GetMaxFeature(self.data)
            if(get_time_data):#get an x,y base on time frame
                self.y = self.data.loc[:,"target"]
                self.x = self.data.drop(columns=["row_id","target"])
                self.x.loc[:,"time_id"] -=self.x.loc[0,"time_id"]
                #self.id = self.x[["time_id"]]
                self.id = self.x[["investment_id"]]
                self.x = self.x.drop(columns=["investment_id"])
                #self.x = self.x.drop(columns=["time_id"])
            else:#get (x,y) base on investment_id
                self.data = self.data.sort_values(by=["investment_id"])
                self.y = self.data.loc[:,"target"]
                self.x = self.data.drop(columns=["row_id","time_id","target"])
                self.id = self.x[["investment_id"]]
                self.x = self.x.drop(columns=["investment_id"])
        
        #pad context before the data
        self.context = context
        self.pad_id =np.pad(self.id.to_numpy(),((context-1,0),(0,0)),constant_values = 0)
        self.pad_x =np.pad(self.x.to_numpy(),((context-1,0),(0,0)),constant_values = 0)
        self.y =self.y.to_numpy()
        
        
        self.pad_id =torch.LongTensor(self.pad_id)
        self.pad_x = torch.FloatTensor(self.pad_x)
        self.y = torch.FloatTensor(self.y)
        
        print(f"succesfully load data with shape x : {self.x.shape} | shape y :{self.y.shape} | get time data is: {get_time_data}")
        
                
            
    def __getitem__(self,index):
        context = self.context
        return self.pad_id[index:index+context],self.pad_x[index:index+context],self.y[index]
        
    def __len__(self):
        return self.x.shape[0]
    
    def GetSize(self):
        if(get_time_data):
            return self.time_size
        else:
            return self.id_size

# %%
def LoadData(get_time_data = True):
    GetDataFromKaggle()
    trainSet =Ubiquant(path+targetpath,context = config["context"], get_time_data = get_time_data)
    valSet =Ubiquant(path+valpath, context = config["context"], get_time_data = get_time_data)
    # testSet =Ubiquant(path+testpath, context = config["context"], get_time_data = get_time_data)
    trainLoader = DataLoader(trainSet,batch_size = config["batch_size"],shuffle =True,drop_last=True)#,num_workers=2)
    valLoader = DataLoader(valSet,batch_size = config["batch_size"],shuffle =True,drop_last=True)#,num_workers=2)
    # testLoader = DataLoader(testSet,batch_size = config["batch_size"],shuffle =False,drop_last=False)
    # return trainLoader,valLoader,testLoader
    return trainLoader,valLoader

# %%
class SimpleAttention(nn.Module):
    def __init__(self,seq_len = 32, input_feature =311):
        super(SimpleAttention,self).__init__() 
        
        self.id_embedding = nn.Embedding(10000,11)
        self.att = nn.MultiheadAttention(input_feature,8,batch_first=True)
        self.flat = nn.Flatten()
        self.MLP =nn.Sequential(
            nn.Linear(input_feature*seq_len,64),
            nn.BatchNorm1d(64),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(64,128),
            nn.BatchNorm1d(128),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(128,256),
            nn.BatchNorm1d(256),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(256,512),
            nn.BatchNorm1d(512),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(512,256),
            nn.BatchNorm1d(256),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(256,128),
            nn.BatchNorm1d(128),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(128,8),
            nn.BatchNorm1d(8),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(8,1)
        )
            
        self.criterion = nn.MSELoss()
        
    def forward(self,_id,f_features):
        invest_embedding = self.id_embedding(_id).squeeze(dim=2)
        #print(invest_embedding.shape)
        #print(f_features.shape)
        _input =torch.cat((invest_embedding,f_features),axis =-1)
        #print(_input.shape)
        #_input = _input.unsqueeze(dim=1)
        #print(_input.shape)
        output,_ = self.att(_input,_input,_input)
        #print(output.shape)
        output = self.flat(output)
        #print(output.shape)
        output = self.MLP(output)
        return output
    
    def cal_Loss(self,y_hat,y):
        return self.criterion(y_hat,y)

# %%
class SimpleMLP(nn.Module):
    def __init__(self,seq_len = 32,input_feature = 311):
        super(SimpleMLP,self).__init__()
        
        self.id_embedding = nn.Embedding(10000,11)
        self.flat = nn.Flatten()
        self.MLP =nn.Sequential(
            nn.Linear(input_feature*seq_len,64),
            nn.BatchNorm1d(64),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(64,128),
            nn.BatchNorm1d(128),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(128,256),
            nn.BatchNorm1d(256),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(256,512),
            nn.BatchNorm1d(512),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(512,256),
            nn.BatchNorm1d(256),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(256,128),
            nn.BatchNorm1d(128),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(128,8),
            nn.BatchNorm1d(8),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(8,1)
        )
        
        self.criterion = nn.MSELoss()
        
    def forward(self,_id,f_features):
        invest_embedding = self.id_embedding(_id).squeeze(dim=2)
        #print(invest_embedding.shape)
        #print(f_features.shape)
        _input =torch.cat((invest_embedding,f_features),axis =-1)
        #print(_input.shape)
        #_input = _input.unsqueeze(dim=1)
        #print(_input.shape)
        _input = self.flat(_input)
        output = self.MLP(_input)
        return output

    def cal_Loss(self,y_hat,y):
        return self.criterion(y_hat,y)

# %%
def get_corr(y,target):
    y,target = y.reshape(-1),target.reshape(-1)
    ymean,targetmean = torch.mean(y),torch.mean(target)
    
    vy = y-ymean
    vt = target-targetmean
    
    corr = torch.sum(vy*vt)/(torch.sqrt(torch.sum(vy**2))* torch.sqrt(torch.sum(vt**2)))
    return corr

# %%
def train(model,trainLoader,valLoader, optimizer, scheduler, config):
    best_loss =1000
    epochs =config["epoch"]
    for epoch in range(epochs):
        batch_bar = tqdm(total = len(trainLoader),dynamic_ncols = True,leave =False,position = 0,desc = "train")
        model.train()
        train_total_loss = 0
        for i,(x1,x2,y) in enumerate(trainLoader):
            optimizer.zero_grad()
            x1,x2,y = x1.cuda(),x2.cuda(),y.cuda()
            y_hat = model(x1,x2)
            y_hat = y_hat.reshape(-1,1)
            y =y.reshape(-1,1)
            loss = model.cal_Loss(y_hat,y)
            train_total_loss+=float(loss.cpu())
            batch_bar.set_postfix(
                loss="{:.04f}".format(float(train_total_loss / (i + 1))),
                lr="{:.04f}".format(float(optimizer.param_groups[0]['lr'])))
            loss.backward()
            optimizer.step()
            scheduler.step()
            batch_bar.update()
        batch_bar.close()
        
        val_total_loss = 0
        val_total_corr = 0
        batch_bar = tqdm(total = len(valLoader),dynamic_ncols = True,leave =False,position = 0,desc = "val")
        model.eval()
        for i,(x1,x2,y) in enumerate(valLoader):
            with torch.no_grad():
                x1,x2,y = x1.cuda(),x2.cuda(),y.cuda()
                y_hat = model(x1,x2)
                y_hat = y_hat.reshape(-1,1)
                y =y.reshape(-1,1)
                loss = model.cal_Loss(y_hat,y)
                

                corr = get_corr(y_hat,y)
                val_total_corr+=corr
               
                val_total_loss+=loss
            batch_bar.set_postfix(
                loss="{:.04f}".format(float(val_total_loss / (i + 1))),
                
                corr="{:.04f}".format(float(val_total_corr / (i + 1))),
             )
            batch_bar.update()
        batch_bar.close()
        val_loss = float(val_total_loss/len(valLoader))
        if(val_loss<best_loss):
            best_loss = val_loss
            torch.save(model.state_dict(),config["store_path"])
            print("successfully save model")
        
        print(f"Epoch {epoch+1}/{epochs}: train loss {float(train_total_loss / len(trainLoader)):0.04f}, Learning Rate {optimizer.param_groups[0]['lr']:0.04f}, val loss{float(val_total_loss/len(valLoader)):0.04f}, corr {float(val_total_corr / (i + 1)):0.04f}")

# %%
def test(model,testLoader,config):
    model.load_state_dict(torch.load(config["store_path"]))
    model.eval()
    test_total_loss = 0
    test_total_corr = 0
    batch_bar = tqdm(total = len(testLoader),dynamic_ncols = True,leave =False,position = 0,desc = "Test")
    for i,(x1,x2,y) in enumerate(testLoader):
        with torch.no_grad():
            x1,x2,y = x1.cuda(),x2.cuda(),y.cuda()
            y_hat = model(x1,x2)
            y_hat = y_hat.reshape(-1,1)
            y =y.reshape(-1,1)
            loss = model.cal_Loss(y_hat,y)
                

            corr = get_corr(y_hat,y)
            test_total_corr+=corr
            test_total_loss+=loss
        batch_bar.set_postfix(
                test_loss="{:.04f}".format(float(test_total_loss / (i + 1))),
                
                test_corr="{:.04f}".format(float(test_total_corr / (i + 1))),
             )
        batch_bar.update()
    batch_bar.close()
    print(f"test loss{float(test_total_loss/len(testLoader)):0.04f},test corr {float(test_total_corr / len(testLoader)):0.04f}")

# %%
def Main():
    #set all parameter
    trainLoader,valLoader = LoadData(get_time_data = True)
    model = SimpleAttention(32,312).cuda()
    model.train()
    baseline_model = SimpleMLP(32,312).cuda()
    baseline_model.train()
    optimizer = getattr(torch.optim,config["optimz"])(model.parameters(),lr =config["learning_rate"])
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=(len(trainLoader) * config["epoch"]))
    
    
    base_optimizer = getattr(torch.optim,config["optimz"])(model.parameters(),lr =config["learning_rate"])
    base_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=(len(trainLoader) * config["epoch"]))
    #params
    num_para =0
    for p in model.parameters():
        num_para+=p.numel()
    print(f'Number of params : {num_para}')
    
    train(model,trainLoader,valLoader,optimizer,scheduler,config)
    print("///////////Start Train Base Line//////////")
    train(baseline_model,trainLoader,valLoader,base_optimizer,base_scheduler,base_config)
    
    # print("//////////Start test///////////")
    # print("----BaseLine-----")
    # test(baseline_model,testLoader,base_config)
    # print("----Attention-----")
    # test(model,testLoader,config)

# %%
config={"epoch" : 50,"batch_size":12800,"learning_rate":0.1,"optimz":"Adam","store_path":"/content/Att.pth","context":32}

# %%
base_config={"epoch" : 50,"batch_size":12800,"learning_rate":0.1,"optimz":"Adam","store_path":"/content/MLP.pth","context":32}

# %%
Main()
# Out:
# succesfully load data with shape x : (2513128, 301) | shape y :torch.Size([2513128]) | get time data is: True
# succesfully load data with shape x : (628282, 301) | shape y :torch.Size([628282]) | get time data is: True
# Number of params : 1480561
# successfully save model
# Epoch 1/50: train loss 0.8487, Learning Rate 0.0999, val loss0.8176, corr 0.0014
# Epoch 2/50: train loss 0.8462, Learning Rate 0.0996, val loss0.8178, corr 0.0055
# Epoch 3/50: train loss 0.8461, Learning Rate 0.0991, val loss0.8178, corr 0.0062
# Epoch 4/50: train loss 0.8462, Learning Rate 0.0984, val loss0.8179, corr -0.0049
# Epoch 5/50: train loss 0.8460, Learning Rate 0.0976, val loss0.8190, corr -0.0054
# Epoch 6/50: train loss 0.8462, Learning Rate 0.0965, val loss0.8179, corr -0.0107
# Epoch 7/50: train loss 0.8460, Learning Rate 0.0952, val loss0.8177, corr -0.0014
# successfully save model
# Epoch 8/50: train loss 0.8461, Learning Rate 0.0938, val loss0.8176, corr 0.0041
# Epoch 9/50: train loss 0.8462, Learning Rate 0.0922, val loss0.8178, corr 0.0012
# Epoch 10/50: train loss 0.8461, Learning Rate 0.0905, val loss0.8177, corr 0.0014
# train:  45%|████▌     | 89/196 [01:30<01:49,  1.02s/it, loss=0.8461, lr=0.0896]

# %%
a1 = pd.read_feather("/content/train.ftr")

# %%
a1.head(10)
# Out:
#      row_id  time_id  investment_id    target       f_0       f_1       f_2  \
# 0  707_2916      707           2916 -0.608887  0.019150 -1.291016 -1.386719
# 1  496_1846      496           1846 -0.667480  0.189331 -0.632324  1.246094
# 2   307_959      307            959 -0.302490  0.008827 -0.455322 -1.005859
# 3  562_1475      562           1475 -2.234375 -0.536133  1.165039 -1.202148
# 4  421_2229      421           2229 -0.388428  0.404053  0.308594  0.402832
# 5  411_3151      411           3151  0.107178  0.000000  1.505859 -0.503418
# 6  984_2640      984           2640  0.331055  0.219849  0.403809  1.997070
# 7   177_771      177            771  1.785156 -0.319580  0.833496 -1.462891
# 8   87_2761       87           2761  0.019669  0.447021 -1.597656  0.684570
# 9  570_2074      570           2074 -0.344238  0.901367 -1.420898  1.189453
#
#         f_3       f_4       f_5  ...     f_290     f_291     f_292     f_293  \
# 0 -0.132080 -0.227173 -2.048828  ...  0.836426  1.171875 -0.964844  0.078491
# 1 -0.151367 -0.533691 -0.375732  ... -1.458984 -0.495117 -0.037292 -0.986328
# 2  0.686523  0.079529  0.528809  ...  0.954102  0.302246  0.221191  1.644531
# 3  1.009766  0.506836 -0.350586  ... -1.800781  1.994141 -1.164062  0.440674
# 4 -0.183960 -0.349365 -0.404541  ... -0.894531  1.023438 -0.497070  0.201660
# 5 -0.001770 -0.169434 -1.294922  ...  2.101562 -0.479492 -0.056122 -3.970703
# 6 -0.336426 -0.216675 -1.012695  ... -1.625977  0.240356 -0.725098  0.874023
# 7  1.552734  1.860352 -2.466797  ...  0.151245  1.770508  0.488281  0.219604
# 8 -0.304688 -0.294678  0.105957  ...  0.376709 -0.369385 -0.252930  0.077087
# 9  1.755859 -0.297119 -2.037109  ... -0.404053  0.609863  1.772461  0.651367
#
#       f_294     f_295     f_296     f_297     f_298     f_299
# 0  1.573242 -0.186035  2.007812  2.230469  0.433838 -0.205566
# 1 -0.527344 -0.765137  0.610352 -0.000275 -0.118408 -0.688477
# 2  0.831055  0.159058  0.399658 -2.341797  0.248291  0.520020
# 3 -0.607422  0.388428 -0.616699  0.999023  0.446777  0.274902
# 4  0.475586 -0.172607  1.695312  1.160156 -1.679688 -0.391846
# 5  1.813477 -0.212402 -1.339844  0.112122  0.000000 -0.947266
# 6  0.937500 -0.486572 -0.830566  0.365723 -0.939453 -0.363770
# 7  0.711914  1.416016 -1.156250 -1.015625  1.428711  5.445312
# 8 -0.544922 -0.201172 -0.449219 -0.631836  0.732910 -0.150879
# 9 -0.658203  0.121643  1.126953  0.342773 -2.154297  0.025116
#
# [10 rows x 304 columns]

# %%
df.head(10)
# Out:
#   row_id  time_id  investment_id    target       f_0       f_1       f_2  \
# 0    0_1        0              1 -0.300781  0.932617  0.113708 -0.402100
# 1    0_2        0              2 -0.231079  0.811035 -0.514160  0.742188
# 2    0_6        0              6  0.568848  0.394043  0.615723  0.567871
# 3    0_7        0              7 -1.064453 -2.343750 -0.011871  1.875000
# 4    0_8        0              8 -0.531738  0.842285 -0.262939  2.330078
# 5    0_9        0              9  1.505859  0.608887  1.369141 -0.761719
# 6   0_10        0             10 -0.260742 -1.864258  0.113708  1.574219
# 7   0_12        0             12 -0.469238  0.408936 -0.765137  0.261475
# 8   0_13        0             13  0.094543  0.861328  2.373047 -1.149414
# 9   0_14        0             14 -0.251221 -2.476562  0.239258  2.222656
#
#         f_3       f_4       f_5  ...     f_290     f_291     f_292     f_293  \
# 0  0.378418 -0.203979 -0.413574  ...  0.365967 -1.095703  0.200073  0.819336
# 1 -0.616699 -0.194214  1.771484  ... -0.154175  0.912598 -0.734375  0.819336
# 2 -0.607910  0.068909 -1.083008  ... -0.138062  0.912598 -0.551758 -1.220703
# 3 -0.606445 -0.586914 -0.815918  ...  0.382080  0.912598 -0.266357 -1.220703
# 4 -0.583496 -0.618164 -0.742676  ... -0.170410  0.912598 -0.741211 -1.220703
# 5  0.865723 -0.359375 -1.835938  ...  0.333740 -1.095703 -0.335938  0.819336
# 6 -0.598633 -0.569824  0.398682  ...  0.821777  0.912598  0.476318 -1.220703
# 7 -0.591797 -0.037262  0.668945  ...  0.821777 -1.095703 -0.864258 -1.220703
# 8  0.752441 -0.050507 -2.250000  ... -0.658203  0.912598  0.718262  0.819336
# 9 -0.582520 -0.618164  0.386230  ...  0.821777 -1.095703 -0.615723 -1.220703
#
#       f_294     f_295     f_296     f_297     f_298     f_299
# 0  0.941406 -0.086792 -1.086914 -1.044922 -0.287598  0.321533
# 1  0.941406 -0.387695 -1.086914 -0.929688 -0.974121 -0.343506
# 2 -1.060547 -0.219116 -1.086914 -0.612305 -0.113953  0.243652
# 3  0.941406 -0.608887  0.104919 -0.783203  1.151367 -0.773438
# 4  0.941406 -0.588379  0.104919  0.753418  1.345703 -0.737793
# 5 -1.060547 -0.343750 -1.086914  0.077881  0.142944 -0.055542
# 6  0.941406 -0.434326  1.296875  0.171387  1.051758 -0.745117
# 7 -1.060547 -0.300293  1.296875 -0.779785  0.274902 -0.182495
# 8  0.941406  4.199219  1.296875  1.854492  0.000000 -0.688477
# 9 -1.060547 -0.647949  0.104919 -0.849609  0.805664 -0.820312
#
# [10 rows x 304 columns]
